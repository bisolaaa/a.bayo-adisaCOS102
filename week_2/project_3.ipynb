# %%
# : Finalized Student Records

# Data Entry with your specific data
students = [
    # Girls
    {"name": "Evelyn", "gender": "F", "age": 17, "height": 5.5, "score": 80},
    {"name": "Jessica", "gender": "F", "age": 16, "height": 6.0, "score": 85},
    {"name": "Somto", "gender": "F", "age": 17, "height": 5.4, "score": 70},
    {"name": "Edith", "gender": "F", "age": 18, "height": 5.9, "score": 60},
    {"name": "Liza", "gender": "F", "age": 16, "height": 5.6, "score": 76},
    {"name": "Madonna", "gender": "F", "age": 18, "height": 5.5, "score": 66},
    {"name": "Waje", "gender": "F", "age": 17, "height": 6.1, "score": 87},
    {"name": "Tola", "gender": "F", "age": 20, "height": 6.0, "score": 95},
    {"name": "Aisha", "gender": "F", "age": 19, "height": 5.7, "score": 50},
    {"name": "Latifa", "gender": "F", "age": 17, "height": 5.5, "score": 49},
    # Boys
    {"name": "Chinedu", "gender": "M", "age": 18, "height": 1.78, "score": 74},
    {"name": "Liam", "gender": "M", "age": 17, "height": 1.80, "score": 87},
    {"name": "Wale", "gender": "M", "age": 19, "height": 1.75, "score": 75},
    {"name": "Gbenga", "gender": "M", "age": 16, "height": 1.74, "score": 68},
    {"name": "Abiola", "gender": "M", "age": 18, "height": 1.82, "score": 66},
    {"name": "Kola", "gender": "M", "age": 17, "height": 1.77, "score": 78},
    {"name": "Kunle", "gender": "M", "age": 19, "height": 1.85, "score": 87},
    {"name": "George", "gender": "M", "age": 16, "height": 1.79, "score": 98},
    {"name": "Thomas", "gender": "M", "age": 18, "height": 1.81, "score": 54},
    {"name": "Wesly", "gender": "M", "age": 17, "height": 1.76, "score": 54.60}
]

def print_header():
    print(f"{'NAME':<12} | {'AGE':<5} | {'HEIGHT':<8} | {'SCORE':<5}")
    print("-" * 45)

# Display Girls
print("\n[ RECORDS FOR GIRLS ]")
print_header()
for s in students:
    if s["gender"] == "F":
        print(f"{s['name']:<12} | {s['age']:<5} | {s['height']:<8.2f} | {s['score']:<5}")

# Display Boys
print("\n[ RECORDS FOR BOYS ]")
print_header()
for s in students:
    if s["gender"] == "M":
        print(f"{s['name']:<12} | {s['age']:<5} | {s['height']:<8.2f} | {s['score']:<5}")
# Out:
# [ RECORDS FOR GIRLS ]
# NAME         | AGE   | HEIGHT   | SCORE
# ---------------------------------------------
# Evelyn       | 17    | 5.50     | 80
# Jessica      | 16    | 6.00     | 85
# Somto        | 17    | 5.40     | 70
# Edith        | 18    | 5.90     | 60
# Liza         | 16    | 5.60     | 76
# Madonna      | 18    | 5.50     | 66
# Waje         | 17    | 6.10     | 87
# Tola         | 20    | 6.00     | 95
# Aisha        | 19    | 5.70     | 50
# Latifa       | 17    | 5.50     | 49
#
# [ RECORDS FOR BOYS ]
# NAME         | AGE   | HEIGHT   | SCORE
# ---------------------------------------------
# Chinedu      | 18    | 1.78     | 74
# Liam         | 17    | 1.80     | 87
# Wale         | 19    | 1.75     | 75
# Gbenga       | 16    | 1.74     | 68
# Abiola       | 18    | 1.82     | 66
# Kola         | 17    | 1.77     | 78
# Kunle        | 19    | 1.85     | 87
# George       | 16    | 1.79     | 98
# Thomas       | 18    | 1.81     | 54
# ...

# %%
# algorithm
1. Start
2. Create Data Lists
- Create a list for girls’ names.
- Create a list for girls’ ages.
- Create a list for girls’ heights.
- Create a list for girls’ scores.
- Repeat the same four lists for boys.
3. Combine the Data
- Create an empty list called students.
- For each girl (index 0 to 9):
- Create a record containing:
- Name
- Age
- Height
- Score
- Gender = “Female”
- Append the record to students.
- For each boy (index 0 to 9):
- Create a similar record with Gender = “Male”.
- Append the record to students.
4. Prepare Table Structure
- Define table headers: Name, Age, Height, Score, Gender.
5. Display the Table
- For each record in students:
- Print the values in a row under the appropriate headers.
6. End
