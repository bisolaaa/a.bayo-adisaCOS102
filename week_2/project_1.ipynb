# %% [markdown]
# week-2 project1 a and b
# ![weekk2 project 1 - Word 3_15_2026 8_08_49 PM.png](attachment:03d0c5dc-efac-4778-ad5f-38e9b6e1a304.png)![weekk2 project 1 - Word 3_15_2026 8_08_58 PM.png](attachment:b24a9e05-dfec-41b1-a0db-18694dd7abfa.png)

# %%
week-2 project1 c
- Start
- Input the first person’s name and age
- Input the second person’s name and age
- Store the first person’s age in a temporary variable
- Assign the second person’s age to the first person
- Assign the temporary variable (original first age) to the second person
- Output both names with their new swapped ages
- End

pseudocode version

START

INPUT name1, age1
INPUT name2, age2

temp ← age1
age1 ← age2
age2 ← temp

OUTPUT name1, age1
OUTPUT name2, age2

END
